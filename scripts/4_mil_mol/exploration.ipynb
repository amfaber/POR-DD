# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_parquet("/home/qzj517/POR-DD/data/gnina_processed/4_mil_mol/molprops.parquet")

# %%
plt.hist(df["CNNaffinity"], bins = 100)
pass
