# %%
import rdkit.Chem as Chem
import os
import pandas as pd
from futils import ROOT
curdir, _, files = next(os.walk(ROOT / "data/Glide files"))
mae_files = [os.path.join(curdir, file) for file in files if file.endswith(".mae")]
import numpy as np
import nglview as nv
from futils import poseview

# %%
all_mols = {mae.split("/")[-1]: list(Chem.MaeMolSupplier(mae)) for mae in mae_files}
# Out:
# [11:00:13]
#
# ****
# Invariant Violation
# bad stereo bond
# Violation occurred on line 205 in file /home/conda/feedstock_root/build_artifacts/rdkit_1651075184788/work/Code/GraphMol/FileParsers/MaeMolSupplier.cpp
# Failed Expression: bond->getBondType() == Bond::DOUBLE
# ****
#
# [11:00:13]
#
# ****
# Invariant Violation
# bad chiral bond
# Violation occurred on line 163 in file /home/conda/feedstock_root/build_artifacts/rdkit_1651075184788/work/Code/GraphMol/FileParsers/MaeMolSupplier.cpp
# Failed Expression: bnd
# ****
#
# [11:00:13]
#
# ****
# Invariant Violation
# bad stereo bond
# Violation occurred on line 205 in file /home/conda/feedstock_root/build_artifacts/rdkit_1651075184788/work/Code/GraphMol/FileParsers/MaeMolSupplier.cpp
# Failed Expression: bond->getBondType() == Bond::DOUBLE
# ****
#
# [11:00:13]
#
# ****
# Invariant Violation
# bad stereo bond
# ...

# %%
[len(val) for val in all_mols.values()]
# Out:
# [1754, 3253, 1578, 1717, 1754, 1756]

# %%
keys = list(all_mols.keys())
names_of_8 = [mol.GetProp("_Name") for mol in all_mols[keys[1]] if mol]

# %%
[mol.GetProp("_Name") for mol in all_mols["8.mae"][:4]]
# Out:
# ['Pyridoxal Phosphate',
#  'Pyridoxal Phosphate',
#  'Pyridoxal Phosphate',
#  'Pyridoxal Phosphate']

# %%
wid = nv.NGLWidget()
[wid.add_component(mol) for mol in all_mols["8.mae"][:4]]
wid.add_component(prot)
wid
# Out:
# NGLWidget()

# %%
all_mols["5.mae"][0].GetProp("_Name")
# Out:
# '3QE2 - preprocessed'

# %%
def get_prot(mol_list):
    for i_prot in range(len(mol_list)):
        mol = mol_list[i_prot]
        if mol and mol.GetProp("_Name") == '3QE2 - preprocessed':
            break
    prot = mol_list[i_prot]
    return prot

# %%
prots = [get_prot(mol_list) for mol_list in all_mols.values()]

# %%
protcoords = [prot.GetConformer().GetPositions() for prot in prots]

# %%
ref = protcoords[0]

# %%
test = [(protcoord == ref) for protcoord in protcoords]
# Out:
# /home/qzj517/anaconda3/envs/equibind/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   """Entry point for launching an IPython kernel.

# %%
all_mols["1.mae"]
# Out:
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  None,
# ...
#  ...]

# %%
prots[-1]

# %%
protcoords[0].shape
# Out:
# (4951, 3)

# %%
protcoords[3].shape
# Out:
# (4975, 3)

# %%
protcoords[3] == protcoords[0]
# Out:
# /home/qzj517/anaconda3/envs/equibind/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   """Entry point for launching an IPython kernel.
# False

# %%
prots[3]

# %%
keys[3]
# Out:
# '2.mae'

# %%
[mol.GetProp("_Name") for mol in all_mols["8.mae"][:4]]

# %%
names, counts = np.unique(names_of_5, return_counts=True)

# %%
len(names[np.nonzero(counts > 1)])
# Out:
# 441

# %%
len(names)
# Out:
# 1183

# %%
idk = bp.PDBList().retrieve_pdb_file("3QE2", file_format = "pdb")

# %%
p = bp.PDBParser()
s = p.get_structure("", idk)
# Out:
# /home/qzj517/anaconda3/envs/equibind/lib/python3.7/site-packages/Bio/PDB/StructureBuilder.py:92: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 10374.
#   PDBConstructionWarning,
# /home/qzj517/anaconda3/envs/equibind/lib/python3.7/site-packages/Bio/PDB/StructureBuilder.py:92: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 10490.
#   PDBConstructionWarning,
# /home/qzj517/anaconda3/envs/equibind/lib/python3.7/site-packages/Bio/PDB/StructureBuilder.py:92: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 10605.
#   PDBConstructionWarning,
# /home/qzj517/anaconda3/envs/equibind/lib/python3.7/site-packages/Bio/PDB/StructureBuilder.py:92: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 11201.
#   PDBConstructionWarning,

# %%
test = s[0]["A"]

# %%
len(list(test.get_atoms()))
# Out:
# 5548

# %%
mols = [mol for mol in supp]
# Out:
# [16:09:51]
#
# ****
# Invariant Violation
# bad stereo bond
# Violation occurred on line 205 in file /home/conda/feedstock_root/build_artifacts/rdkit_1651075184788/work/Code/GraphMol/FileParsers/MaeMolSupplier.cpp
# Failed Expression: bond->getBondType() == Bond::DOUBLE
# ****
#
# [16:09:51]
#
# ****
# Invariant Violation
# bad stereo bond
# Violation occurred on line 205 in file /home/conda/feedstock_root/build_artifacts/rdkit_1651075184788/work/Code/GraphMol/FileParsers/MaeMolSupplier.cpp
# Failed Expression: bond->getBondType() == Bond::DOUBLE
# ****
#
# [16:09:51]
#
# ****
# Invariant Violation
# bad stereo bond
# Violation occurred on line 205 in file /home/conda/feedstock_root/build_artifacts/rdkit_1651075184788/work/Code/GraphMol/FileParsers/MaeMolSupplier.cpp
# Failed Expression: bond->getBondType() == Bond::DOUBLE
# ****
#
# [16:09:51]
#
# ****
# Invariant Violation
# bad stereo bond
# ...

# %%
mols[0]

# %%
mols[0].GetConformer().GetPositions()
# Out:
# (4951, 3)

# %%
{name: mols[1].GetProp(name) for name in  mols[1].GetPropNames()}
# Out:
# {'s_epik_cmdline': 'J2VwaWtfcHl0aG9uJywgJy1waCcsICc3LjAnLCAnLW50JywgJy1tYScsICcyMDAnLCAnLWltYWUnLCAnPGluZmlsZS5tYWU+JywgJy1vbWFlJywgJzxvdXRmaWxlLm1hZT4n',
#  's_epik_input': 'Tz1bQ0hdW05IXWMoYyhbT0hdKVtjSF1bY0hdMSlbY0hdYzFbQ0BIXShbT0hdKVtDSDJdW05IXVtDQEhdKFtDSDNdKVtDSDJdYzJbY0hdW2NIXWMoT1tDSDNdKVtjSF1bY0hdMg==',
#  's_i_glide_gridfile': 'glide-grid_1',
#  's_lp_Force_Field': 'OPLS3e',
#  's_lp_Variant': 'Formoterol-1',
#  's_m_Source_File': 'test_3D_opt_1216.sdf',
#  's_m_Source_Path': '/Users/xvk760/Desktop/Nikos_Hatzakis/Docking/190524 Library prep',
#  's_m_entry_id': '12532',
#  's_m_entry_name': 'test_3D_opt_1216.495',
#  's_m_job_name': 'glide-grid_1_drugbank_docking',
#  's_m_source_file': 'ligprep_3D_opt_1216.maegz',
#  's_m_subgroup_title': 'glide-grid_1_drugbank_docking_pv1',
#  's_m_subgroupid': 'glide-grid_1_drugbank_docking_pv1',
#  's_sd_Converged': 'true',
#  's_sd_DATABASE\\_ID': 'DB00983',
#  's_sd_GENERIC\\_NAME': 'Formoterol',
# ...
