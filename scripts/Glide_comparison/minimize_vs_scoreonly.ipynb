# %%
from loaders import *
from comparison_util import *
data = load_scoreonly("/home/amfaber/gnina_own/results/equibind_score_only").merge(
load_equibind("/home/amfaber/gnina_own/results/equibind_dock_real").rename(columns={"affinity1": "Affinity"}), on = "name")
data = data.merge(load_index(), on = "name")

# %%
Linreg(data.CNNaffinity_x, data.CNNaffinity_y)

# %%
Linreg(data.CNNaffinity_x, data.aff)

# %%
Linreg(data.CNNaffinity_y, data.aff)

# %%
mask = data.CNNscore_y>0.5
Linreg(data.CNNaffinity_y[mask], data.aff[mask])

# %%
mask = data.CNNscore_x>0.2
Linreg(data.CNNaffinity_x[mask], data.aff[mask])

# %%
plt.hist(data.CNNscore_x, range = (0, 1), bins = 20)
# Out:
# (array([4703., 1453., 1280., 1780., 1104.,  878.,  911., 1284., 1744.,
#         1162.,  888.,  647.,  413.,  261.,  182.,  122.,  101.,   93.,
#           64.,   13.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(data.CNNscore_y, range = (0, 1), bins = 20)
# Out:
# (array([1120., 1412., 1291., 1278., 1184., 1200., 1155., 1233., 1259.,
#         1074.,  932.,  858.,  689.,  588.,  503.,  551.,  485.,  603.,
#          803.,  865.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ]),
#  <BarContainer object of 20 artists>)
